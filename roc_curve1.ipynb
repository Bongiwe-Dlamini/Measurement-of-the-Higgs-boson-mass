# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulated data (replace with your data)
signal_data = np.random.normal(128.29,1.51 , 609)  # Signal centered at 128 GeV
background_data = np.random.normal(136.04,76.41,  33169)  # Background centered at 120 GeV

# Use decimal steps for cut_values (0.1 GeV steps)
cut_values = np.arange(120, 130, 0.1)
signal_efficiency = []
background_rejection = []

for cut in cut_values:
    signal_pass = signal_data[signal_data > cut]
    background_pass = background_data[background_data > cut]
    signal_eff = len(signal_pass) / len(signal_data)
    background_rej = 1 - (len(background_pass) / len(background_data))
    signal_efficiency.append(signal_eff)
    background_rejection.append(background_rej)

plt.figure()
plt.plot(signal_efficiency, background_rejection, marker='o', linestyle='-', color='b', linewidth=0.5, markersize=3)
plt.xlabel('Signal Efficiency')
plt.ylabel('Background Rejection')
plt.title('Signal Efficiency vs. Background Rejection')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.savefig('signal_eff_vs_bkg_rej.png')
